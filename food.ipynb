# %%
# !pip install pandas

# %%
import pandas as pd

# CSV 파일 경로
file_path = './fulldata_07_24_04_P_일반음식점.csv'

# %%
# CSV 파일 읽기
data = pd.read_csv(file_path, encoding='cp949', low_memory=False)

# 데이터 확인
data
# Out:
#               번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 0              1  일반음식점  07_24_04_P   3170000  3170000-101-2022-00099
# 1              2  일반음식점  07_24_04_P   3000000  3000000-101-2022-00116
# 2              3  일반음식점  07_24_04_P   3220000  3220000-101-2022-00618
# 3              4  일반음식점  07_24_04_P   4010000  4010000-101-2022-00334
# 4              5  일반음식점  07_24_04_P   3180000  3180000-101-2022-00228
# ...          ...    ...         ...       ...                     ...
# 2079992  2079993  일반음식점  07_24_04_P   3600000  3600000-101-1995-00101
# 2079993  2079994  일반음식점  07_24_04_P   3610000  3610000-101-2012-00009
# 2079994  2079995  일반음식점  07_24_04_P   3610000  3610000-101-2014-00098
# 2079995  2079996  일반음식점  07_24_04_P   3600000  3600000-101-2014-00060
# 2079996  2079997  일반음식점  07_24_04_P   3600000  3600000-101-2014-00059
#
#               인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직직원수 건물소유구분명  \
# ...

# %%
data = data[data['영업상태명'] != '폐업']

# %%
data
# Out:
#               번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 1384182  1384183  일반음식점  07_24_04_P   3780000  3790000-101-2022-00126
# 1384183  1384184  일반음식점  07_24_04_P   4080000  4080000-101-2022-00092
# 1384184  1384185  일반음식점  07_24_04_P   4080000  4080000-101-2022-00091
# 1384185  1384186  일반음식점  07_24_04_P   3180000  3180000-101-2022-00229
# 1384186  1384187  일반음식점  07_24_04_P   5380000  5380000-101-2022-00198
# ...          ...    ...         ...       ...                     ...
# 2079992  2079993  일반음식점  07_24_04_P   3600000  3600000-101-1995-00101
# 2079993  2079994  일반음식점  07_24_04_P   3610000  3610000-101-2012-00009
# 2079994  2079995  일반음식점  07_24_04_P   3610000  3610000-101-2014-00098
# 2079995  2079996  일반음식점  07_24_04_P   3600000  3600000-101-2014-00060
# 2079996  2079997  일반음식점  07_24_04_P   3600000  3600000-101-2014-00059
#
#               인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직직원수 건물소유구분명  \
# ...

# %%
# 삭제할 열 목록
columns_to_drop = ['번호', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가취소일자', '공장생산직직원수', '건물소유구분명', '보증액', '월세액', '전통업소지정번호', '홈페이지', 'Unnamed: 47']

# %%
data = data.drop(columns=columns_to_drop)
data
# Out:
#         개방서비스명       인허가일자  영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  \
# 1384182  일반음식점  2022-05-17         1  영업/정상         1      영업  NaN     NaN
# 1384183  일반음식점  2022-05-17         1  영업/정상         1      영업  NaN     NaN
# 1384184  일반음식점  2022-05-17         1  영업/정상         1      영업  NaN     NaN
# 1384185  일반음식점  2022-05-17         1  영업/정상         1      영업  NaN     NaN
# 1384186  일반음식점  2022-05-17         1  영업/정상         1      영업  NaN     NaN
# ...        ...         ...       ...    ...       ...     ...  ...     ...
# 2079992  일반음식점  1995-09-01         1  영업/정상         1      영업  NaN     NaN
# 2079993  일반음식점  2012-01-19         1  영업/정상         1      영업  NaN     NaN
# 2079994  일반음식점  2014-06-12         1  영업/정상         1      영업  NaN     NaN
# 2079995  일반음식점  2014-03-21         1  영업/정상         1      영업  NaN     NaN
# 2079996  일반음식점  2014-03-19         1  영업/정상         1      영업  NaN     NaN
#
# ...

# %%
columns_to_drop = ['폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수', '본사직원수', '공장사무직직원수', '공장판매직직원수']

# %%
data = data.drop(columns=columns_to_drop)
data
# Out:
#         개방서비스명       인허가일자  영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명         소재지전화  \
# 1384182  일반음식점  2022-05-17         1  영업/정상         1      영업           NaN
# 1384183  일반음식점  2022-05-17         1  영업/정상         1      영업           NaN
# 1384184  일반음식점  2022-05-17         1  영업/정상         1      영업           NaN
# 1384185  일반음식점  2022-05-17         1  영업/정상         1      영업           NaN
# 1384186  일반음식점  2022-05-17         1  영업/정상         1      영업           NaN
# ...        ...         ...       ...    ...       ...     ...           ...
# 2079992  일반음식점  1995-09-01         1  영업/정상         1      영업  0062374 0679
# 2079993  일반음식점  2012-01-19         1  영업/정상         1      영업           NaN
# 2079994  일반음식점  2014-06-12         1  영업/정상         1      영업  062 369 1582
# 2079995  일반음식점  2014-03-21         1  영업/정상         1      영업           NaN
# 2079996  일반음식점  2014-03-19         1  영업/정상         1      영업           NaN
#
# ...

# %%
columns_to_drop = ['개방서비스명', '인허가일자', '영업상태구분코드', '상세영업상태코드', '상세영업상태명', '소재지면적', '소재지우편번호', '좌표정보(x)', '좌표정보(y)', '남성종사자수', '여성종사자수', '다중이용업소여부', '시설총규모', '전통업소주된음식']

# %%
data = data.drop(columns=columns_to_drop)
data
# Out:
#          영업상태명         소재지전화                       소재지전체주소  \
# 1384182  영업/정상           NaN     경기도 성남시 수정구 신흥동 2562-2 1층
# 1384183  영업/정상           NaN    경기도 안성시 공도읍 만정리 815-1 107호
# 1384184  영업/정상           NaN    경기도 안성시 대덕면 내리 691-6 2층 일부
# 1384185  영업/정상           NaN          서울특별시 영등포구 도림동 76-22
# 1384186  영업/정상           NaN        경상남도 양산시 물금읍 물금리 878-6
# ...        ...           ...                           ...
# 2079992  영업/정상  0062374 0679          광주광역시 서구 용두동 306번지 1
# 2079993  영업/정상           NaN           광주광역시 남구 양림동 374 2층
# 2079994  영업/정상  062 369 1582  광주광역시 남구 월산동 1048-182번지 (1층)
# 2079995  영업/정상           NaN     광주광역시 서구 화정동 332-9번지 (1층)
# 2079996  영업/정상           NaN       광주광역시 서구 화정동 70-61 (1층)
#
#                                         도로명전체주소  도로명우편번호  \
# 1384182   경기도 성남시 수정구 산성대로295번길 9, 1(일부)층 (신흥동)  13354.0
# 1384183  경기도 안성시 공도읍 공도3로 9-9, 공도 일번가타워 1층 107호  17561.0
# 1384184             경기도 안성시 대덕면 중앙대학로 116-1, 2층  17547.0
# ...

# %%
columns_to_drop = ['데이터갱신일자', '위생업태명', '데이터갱신구분', '도로명우편번호', '도로명전체주소', '최종수정시점']
data = data.drop(columns=columns_to_drop)
data
# Out:
#          영업상태명         소재지전화                       소재지전체주소  \
# 1384182  영업/정상           NaN     경기도 성남시 수정구 신흥동 2562-2 1층
# 1384183  영업/정상           NaN    경기도 안성시 공도읍 만정리 815-1 107호
# 1384184  영업/정상           NaN    경기도 안성시 대덕면 내리 691-6 2층 일부
# 1384185  영업/정상           NaN          서울특별시 영등포구 도림동 76-22
# 1384186  영업/정상           NaN        경상남도 양산시 물금읍 물금리 878-6
# ...        ...           ...                           ...
# 2079992  영업/정상  0062374 0679          광주광역시 서구 용두동 306번지 1
# 2079993  영업/정상           NaN           광주광역시 남구 양림동 374 2층
# 2079994  영업/정상  062 369 1582  광주광역시 남구 월산동 1048-182번지 (1층)
# 2079995  영업/정상           NaN     광주광역시 서구 화정동 332-9번지 (1층)
# 2079996  영업/정상           NaN       광주광역시 서구 화정동 70-61 (1층)
#
#                            사업장명  업태구분명
# 1384182  해피딜리버리(Happy delivery)     한식
# 1384183              79대포 안성공도점  호프/통닭
# 1384184          맛있어2(Masisso2)     한식
# 1384185            푸드 딜리버리 영등포점     한식
# 1384186                  수벙샌드위치     기타
# ...

# %%
# 데이터프레임 인덱스 재배열
data = data.reset_index(drop=True)
data
# Out:
#         영업상태명         소재지전화                       소재지전체주소  \
# 0       영업/정상           NaN     경기도 성남시 수정구 신흥동 2562-2 1층
# 1       영업/정상           NaN    경기도 안성시 공도읍 만정리 815-1 107호
# 2       영업/정상           NaN    경기도 안성시 대덕면 내리 691-6 2층 일부
# 3       영업/정상           NaN          서울특별시 영등포구 도림동 76-22
# 4       영업/정상           NaN        경상남도 양산시 물금읍 물금리 878-6
# ...       ...           ...                           ...
# 695810  영업/정상  0062374 0679          광주광역시 서구 용두동 306번지 1
# 695811  영업/정상           NaN           광주광역시 남구 양림동 374 2층
# 695812  영업/정상  062 369 1582  광주광역시 남구 월산동 1048-182번지 (1층)
# 695813  영업/정상           NaN     광주광역시 서구 화정동 332-9번지 (1층)
# 695814  영업/정상           NaN       광주광역시 서구 화정동 70-61 (1층)
#
#                           사업장명  업태구분명
# 0       해피딜리버리(Happy delivery)     한식
# 1                   79대포 안성공도점  호프/통닭
# 2               맛있어2(Masisso2)     한식
# 3                 푸드 딜리버리 영등포점     한식
# 4                       수벙샌드위치     기타
# ...

# %%
# 수정된 데이터프레임을 CSV 파일로 저장
output_file_path = './전국음식점(수정본).csv'
data.to_csv(output_file_path, index=False)

print("CSV 파일이 저장되었습니다.")
# Out:
# CSV 파일이 저장되었습니다.
