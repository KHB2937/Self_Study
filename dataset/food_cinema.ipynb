# %% [markdown]
# <a href="https://colab.research.google.com/github/KHB2937/dataset/blob/main/food_cinema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 음식점

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# CSV 파일 경로
file_path = '/content/drive/MyDrive/Colab Notebooks/fulldata_07_24_04_P_일반음식점.csv'

# %%
# CSV 파일 읽기
data = pd.read_csv(file_path, encoding='cp949', low_memory=False)

# 데이터 확인
data

# %%
data = data[data['영업상태명'] != '폐업']

# %%
data

# %%
# 삭제할 열 목록
columns_to_drop = ['번호', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가취소일자',
                   '공장생산직직원수', '건물소유구분명', '보증액', '월세액', '전통업소지정번호',
                   '홈페이지', 'Unnamed: 47', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '영업장주변구분명',
                   '개방서비스명', '인허가일자', '영업상태구분코드', '상세영업상태코드', '상세영업상태명',
                   '데이터갱신일자', '위생업태명', '데이터갱신구분', '도로명우편번호', '도로명전체주소',
                   '여성종사자수', '등급구분명', '급수시설구분명', '총직원수','본사직원수', '공장사무직직원수',
                   '공장판매직직원수', '다중이용업소여부', '시설총규모', '전통업소주된음식', '남성종사자수', '소재지면적', '소재지우편번호', '최종수정시점']
data = data.drop(columns=columns_to_drop)
data
# Out:
#          영업상태명         소재지전화                       소재지전체주소  \
# 1384182  영업/정상           NaN     경기도 성남시 수정구 신흥동 2562-2 1층
# 1384183  영업/정상           NaN    경기도 안성시 공도읍 만정리 815-1 107호
# 1384184  영업/정상           NaN    경기도 안성시 대덕면 내리 691-6 2층 일부
# 1384185  영업/정상           NaN          서울특별시 영등포구 도림동 76-22
# 1384186  영업/정상           NaN        경상남도 양산시 물금읍 물금리 878-6
# ...        ...           ...                           ...
# 2079992  영업/정상  0062374 0679          광주광역시 서구 용두동 306번지 1
# 2079993  영업/정상           NaN           광주광역시 남구 양림동 374 2층
# 2079994  영업/정상  062 369 1582  광주광역시 남구 월산동 1048-182번지 (1층)
# 2079995  영업/정상           NaN     광주광역시 서구 화정동 332-9번지 (1층)
# 2079996  영업/정상           NaN       광주광역시 서구 화정동 70-61 (1층)
#
#                            사업장명  업태구분명        좌표정보(x)           좌표정보(y)
# 1384182  해피딜리버리(Happy delivery)     한식  213117.592076  437825.856237679
# 1384183              79대포 안성공도점  호프/통닭  215021.103199  388727.667964023
# 1384184          맛있어2(Masisso2)     한식  219857.937502  388861.268105772
# 1384185            푸드 딜리버리 영등포점     한식  191722.709234  445276.999732324
# 1384186                  수벙샌드위치     기타  380741.211631  202644.423181367
# ...                         ...    ...            ...               ...
# 2079992                    원아가든     한식  183338.073439  178369.322568135
# 2079993                     뚱스넥     한식  192085.702260  182111.703093129
# 2079994                 갈비명가아라네     한식  190363.418899  181905.028328142
# 2079995                    승진이네     한식  188322.201767  183130.570775951
# 2079996                      명가     한식  188873.020499  184152.828430449
#
# [695815 rows x 7 columns]

# %%
data

# %%
# 데이터프레임 인덱스 재배열
data = data.reset_index(drop=True)
data

# %%
# 수정된 데이터프레임을 CSV 파일로 저장
output_file_path = './전국음식점(수정본).csv'
data.to_csv(output_file_path, index=False)

print("CSV 파일이 저장되었습니다.")
# Out:
# CSV 파일이 저장되었습니다.

# %% [markdown]
# ## 영화관

# %%
# CSV 파일 경로
file_path = '/content/drive/MyDrive/Colab Notebooks/fulldata_03_13_02_P_영화상영관.csv'
# CSV 파일 읽기
cinema_data = pd.read_csv(file_path, encoding='cp949', low_memory=False)

# 데이터 확인
cinema_data

# %%
cinema_data = cinema_data[cinema_data['영업상태명'] != '폐업']
cinema_data = cinema_data[cinema_data['영업상태명'] != '휴업']

# %%
cinema_data

# %%
# 삭제할 열 목록
columns_to_drop = ['번호', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
                   '영업상태구분코드', '상세영업상태코드', '상세영업상태명', '폐업일자', '소재지면적',
                   '소재지우편번호', '도로명전체주소', '도로명우편번호', '최종수정시점', '데이터갱신구분', '데이터갱신일자',
                   '업태구분명', '문화사업자구분명', '편의시설여부', '소방시설여부', '총게임기수', '기존게임업외업종명', '제공게임물명',
                   '공연장형태구분명', '품목명', '최초등록시점', '지역구분명', 'Unnamed: 59', '주변환경명', '제작취급품목내용',
                   '시설면적', '지상층수', '지하층수', '건물용도명', '통로너비', '조명시설조도', '노래방실수',
                   '휴업시작일자', '휴업종료일자', '재개업일자', '문화체육업종명', '총층수', '청소년실수', '비상계단여부', '비상구여부',
                   '자동환기여부', '청소년실여부', '특수조명여부', '방음시설여부', '비디오재생기명', '조명시설유무', '음향시설여부']
cinema_data = cinema_data.drop(columns=columns_to_drop)
cinema_data
# Out:
#      개방서비스명  영업상태명         소재지전화                        소재지전체주소  \
# 1231  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1232  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1233  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1234  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1235  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# ...     ...    ...           ...                            ...
# 4956  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4957  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4958  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4959  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4960  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
#
#                     사업장명        좌표정보(x)        좌표정보(y)  청소년실수  비상계단여부  비상구여부  \
# 1231        CGV 광주터미널 1관  189004.968213  184579.553645    NaN     NaN    NaN
# 1232        CGV 광주터미널 2관  189004.968213  184579.553645    NaN     NaN    NaN
# 1233        CGV 광주터미널 4관  189004.968213  184579.553645    NaN     NaN    NaN
# 1234        CGV 광주터미널 9관  189004.968213  184579.553645    NaN     NaN    NaN
# 1235  CGV 광주터미널 3관(IMAX)  189004.968213  184579.553645    NaN     NaN    NaN
# ...                  ...            ...            ...    ...     ...    ...
# 4956        메가박스씨네플렉스(주)  205130.591679  445590.096838    NaN     NaN    NaN
# 4957        메가박스씨네플렉스(주)  205130.591679  445590.096838    NaN     NaN    NaN
# 4958        메가박스씨네플렉스(주)  205130.591679  445590.096838    NaN     NaN    NaN
# 4959        메가박스씨네플렉스(주)  205130.591679  445590.096838    NaN     NaN    NaN
# 4960        메가박스씨네플렉스(주)  205130.591679  445590.096838    NaN     NaN    NaN
#
#       자동환기여부  청소년실여부  특수조명여부  방음시설여부  비디오재생기명  조명시설유무  음향시설여부
# 1231     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 1232     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 1233     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 1234     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 1235     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# ...      ...     ...     ...     ...      ...     ...     ...
# 4956     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 4957     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 4958     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 4959     NaN     NaN     NaN     NaN      NaN     NaN     NaN
# 4960     NaN     NaN     NaN     NaN      NaN     NaN     NaN
#
# [3722 rows x 17 columns]

# %%
# 삭제할 열 목록
columns_to_drop = ['청소년실수', '비상계단여부', '비상구여부', '자동환기여부', '청소년실여부', '특수조명여부', '방음시설여부', '비디오재생기명', '조명시설유무', '음향시설여부']
cinema_data = cinema_data.drop(columns=columns_to_drop)
cinema_data
# Out:
#      개방서비스명  영업상태명         소재지전화                        소재지전체주소  \
# 1231  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1232  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1233  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1234  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1235  영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# ...     ...    ...           ...                            ...
# 4956  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4957  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4958  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4959  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 4960  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
#
#                     사업장명        좌표정보(x)        좌표정보(y)
# 1231        CGV 광주터미널 1관  189004.968213  184579.553645
# 1232        CGV 광주터미널 2관  189004.968213  184579.553645
# 1233        CGV 광주터미널 4관  189004.968213  184579.553645
# 1234        CGV 광주터미널 9관  189004.968213  184579.553645
# 1235  CGV 광주터미널 3관(IMAX)  189004.968213  184579.553645
# ...                  ...            ...            ...
# 4956        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 4957        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 4958        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 4959        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 4960        메가박스씨네플렉스(주)  205130.591679  445590.096838
#
# [3722 rows x 7 columns]

# %%
# 데이터프레임 인덱스 재배열
cinema_data = cinema_data.reset_index(drop=True)
cinema_data
# Out:
#      개방서비스명  영업상태명         소재지전화                        소재지전체주소  \
# 0     영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 1     영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 2     영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 3     영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# 4     영화상영관  영업/정상  062-369-3572  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)
# ...     ...    ...           ...                            ...
# 3717  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 3718  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 3719  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 3720  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
# 3721  영화상영관  영업/정상           NaN          서울특별시 강남구 삼성동 159-0번지
#
#                     사업장명        좌표정보(x)        좌표정보(y)
# 0           CGV 광주터미널 1관  189004.968213  184579.553645
# 1           CGV 광주터미널 2관  189004.968213  184579.553645
# 2           CGV 광주터미널 4관  189004.968213  184579.553645
# 3           CGV 광주터미널 9관  189004.968213  184579.553645
# 4     CGV 광주터미널 3관(IMAX)  189004.968213  184579.553645
# ...                  ...            ...            ...
# 3717        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 3718        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 3719        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 3720        메가박스씨네플렉스(주)  205130.591679  445590.096838
# 3721        메가박스씨네플렉스(주)  205130.591679  445590.096838
#
# [3722 rows x 7 columns]

# %%
# 수정된 데이터프레임을 CSV 파일로 저장
output_file_path = './전국영화관(수정본).csv'
cinema_data.to_csv(output_file_path, index=False)

print("CSV 파일이 저장되었습니다.")
# Out:
# CSV 파일이 저장되었습니다.

# %% [markdown]
# ## 공원

# %%
# CSV 파일 경로
file_path = '/content/drive/MyDrive/Colab Notebooks/전국도시공원정보표준데이터.csv'
# CSV 파일 읽기
park_data = pd.read_csv(file_path, encoding='cp949', low_memory=False)
# 데이터 확인
park_data
# Out:
#               관리번호             공원명   공원구분          소재지도로명주소  \
# 0      41390-00084            승지공원   근린공원  경기도 시흥시 능곡중앙로 85
# 1      41570-00059  고촌어린이19(수기1공원)  어린이공원               NaN
# 2      41570-00060  고촌어린이20(수기2공원)  어린이공원               NaN
# 3      41570-00061  고촌어린이21(수기3공원)  어린이공원               NaN
# 4      41570-00063          항공소공원1    소공원               NaN
# ...            ...             ...    ...               ...
# 17281  11500-00044             꿈돌이  어린이공원               NaN
# 17282  11500-00045             소나무  어린이공원               NaN
# 17283  11500-00046              산새  어린이공원               NaN
# 17284  11500-00047              박장  어린이공원               NaN
# 17285  11500-00048              참새  어린이공원               NaN
#
#                       소재지지번주소         위도          경도     공원면적 공원보유시설(운동시설)  \
# 0             경기도 시흥시 능곡동 552  37.371378  126.813132  10842.0          NaN
# 1        경기도 김포시 고촌읍 신곡리 1249  37.600127  126.767372   1715.0          NaN
# 2        경기도 김포시 고촌읍 신곡리 1260  37.596805  126.770145   1522.0       체력단련시설
# 3        경기도 김포시 고촌읍 신곡리 1268  37.596252  126.767048   1567.0          NaN
# 4      경기도 김포시 대곶면 대벽리 산66-56  37.617583  126.580436   1968.0          NaN
# ...                       ...        ...         ...      ...          ...
# 17281    서울특별시 강서구 화곡동 24-128  37.546097  126.845352   1507.0          NaN
# 17282     서울특별시 강서구 화곡동 29-31  37.547058  126.847807    942.0          NaN
# 17283       서울특별시 강서구 화곡동 772  37.546268  126.850385    539.0          NaN
# 17284     서울특별시 강서구 화곡동 56-25  37.540768  126.849087    929.0          NaN
# 17285    서울특별시 강서구 화곡동 56-638  37.539725  126.847003    256.0          NaN
#
#       공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일  \
# 0            조합놀이대          NaN          도서관          NaN  2004-11-10
# 1         조합놀이대+그네          NaN          NaN          NaN  2005-06-07
# 2         조합놀이대+그네          NaN          NaN          NaN  2005-06-07
# 3         조합놀이대+그네          NaN          NaN          NaN  2005-06-07
# 4              NaN          NaN          NaN          NaN  2007-12-17
# ...            ...          ...          ...          ...         ...
# 17281      어린이놀이시설          화장실          NaN          NaN         NaN
# 17282      어린이놀이시설          NaN          NaN          NaN         NaN
# 17283      어린이놀이시설          음수대          NaN          NaN         NaN
# 17284      어린이놀이시설          NaN          NaN          NaN         NaN
# 17285      어린이놀이시설          NaN          NaN          NaN         NaN
#
#                관리기관명          전화번호     데이터기준일자   제공기관코드      제공기관명
# 0           경기도 시흥시청  031-310-3869  2022-11-28  4010000    경기도 시흥시
# 1      경기도 김포시 공원관리과  031-980-5627  2022-10-18  4090000    경기도 김포시
# 2      경기도 김포시 공원관리과  031-980-5627  2022-10-18  4090000    경기도 김포시
# 3      경기도 김포시 공원관리과  031-980-5627  2022-10-18  4090000    경기도 김포시
# 4      경기도 김포시 공원녹지과  031-980-2344  2022-10-18  4090000    경기도 김포시
# ...              ...           ...         ...      ...        ...
# 17281     서울특별시 강서구청  02-2600-4202  2023-03-10  3150000  서울특별시 강서구
# 17282     서울특별시 강서구청  02-2600-4202  2023-03-10  3150000  서울특별시 강서구
# 17283     서울특별시 강서구청  02-2600-4202  2023-03-10  3150000  서울특별시 강서구
# 17284     서울특별시 강서구청  02-2600-4202  2023-03-10  3150000  서울특별시 강서구
# 17285     서울특별시 강서구청  02-2600-4202  2023-03-10  3150000  서울특별시 강서구
#
# [17286 rows x 19 columns]

# %%
# 삭제할 열 목록
columns_to_drop = ['관리번호', '소재지도로명주소', '제공기관코드', '지정고시일', '데이터기준일자', '제공기관코드', '제공기관명']
park_data = park_data.drop(columns=columns_to_drop)
park_data
# Out:
#                   공원명   공원구분                 소재지지번주소         위도          경도  \
# 0                승지공원   근린공원         경기도 시흥시 능곡동 552  37.371378  126.813132
# 1      고촌어린이19(수기1공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1249  37.600127  126.767372
# 2      고촌어린이20(수기2공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1260  37.596805  126.770145
# 3      고촌어린이21(수기3공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1268  37.596252  126.767048
# 4              항공소공원1    소공원  경기도 김포시 대곶면 대벽리 산66-56  37.617583  126.580436
# ...               ...    ...                     ...        ...         ...
# 17281             꿈돌이  어린이공원    서울특별시 강서구 화곡동 24-128  37.546097  126.845352
# 17282             소나무  어린이공원     서울특별시 강서구 화곡동 29-31  37.547058  126.847807
# 17283              산새  어린이공원       서울특별시 강서구 화곡동 772  37.546268  126.850385
# 17284              박장  어린이공원     서울특별시 강서구 화곡동 56-25  37.540768  126.849087
# 17285              참새  어린이공원    서울특별시 강서구 화곡동 56-638  37.539725  126.847003
#
#           공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설)  \
# 0      10842.0          NaN        조합놀이대          NaN          도서관
# 1       1715.0          NaN     조합놀이대+그네          NaN          NaN
# 2       1522.0       체력단련시설     조합놀이대+그네          NaN          NaN
# 3       1567.0          NaN     조합놀이대+그네          NaN          NaN
# 4       1968.0          NaN          NaN          NaN          NaN
# ...        ...          ...          ...          ...          ...
# 17281   1507.0          NaN      어린이놀이시설          화장실          NaN
# 17282    942.0          NaN      어린이놀이시설          NaN          NaN
# 17283    539.0          NaN      어린이놀이시설          음수대          NaN
# 17284    929.0          NaN      어린이놀이시설          NaN          NaN
# 17285    256.0          NaN      어린이놀이시설          NaN          NaN
#
#       공원보유시설(기타시설)          관리기관명          전화번호
# 0              NaN       경기도 시흥시청  031-310-3869
# 1              NaN  경기도 김포시 공원관리과  031-980-5627
# 2              NaN  경기도 김포시 공원관리과  031-980-5627
# 3              NaN  경기도 김포시 공원관리과  031-980-5627
# 4              NaN  경기도 김포시 공원녹지과  031-980-2344
# ...            ...            ...           ...
# 17281          NaN     서울특별시 강서구청  02-2600-4202
# 17282          NaN     서울특별시 강서구청  02-2600-4202
# 17283          NaN     서울특별시 강서구청  02-2600-4202
# 17284          NaN     서울특별시 강서구청  02-2600-4202
# 17285          NaN     서울특별시 강서구청  02-2600-4202
#
# [17286 rows x 13 columns]

# %%
# 데이터프레임 인덱스 재배열
park_data = park_data.reset_index(drop=True)
park_data
# Out:
#                   공원명   공원구분                 소재지지번주소         위도          경도  \
# 0                승지공원   근린공원         경기도 시흥시 능곡동 552  37.371378  126.813132
# 1      고촌어린이19(수기1공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1249  37.600127  126.767372
# 2      고촌어린이20(수기2공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1260  37.596805  126.770145
# 3      고촌어린이21(수기3공원)  어린이공원    경기도 김포시 고촌읍 신곡리 1268  37.596252  126.767048
# 4              항공소공원1    소공원  경기도 김포시 대곶면 대벽리 산66-56  37.617583  126.580436
# ...               ...    ...                     ...        ...         ...
# 17281             꿈돌이  어린이공원    서울특별시 강서구 화곡동 24-128  37.546097  126.845352
# 17282             소나무  어린이공원     서울특별시 강서구 화곡동 29-31  37.547058  126.847807
# 17283              산새  어린이공원       서울특별시 강서구 화곡동 772  37.546268  126.850385
# 17284              박장  어린이공원     서울특별시 강서구 화곡동 56-25  37.540768  126.849087
# 17285              참새  어린이공원    서울특별시 강서구 화곡동 56-638  37.539725  126.847003
#
#           공원면적 공원보유시설(운동시설) 공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설)  \
# 0      10842.0          NaN        조합놀이대          NaN          도서관
# 1       1715.0          NaN     조합놀이대+그네          NaN          NaN
# 2       1522.0       체력단련시설     조합놀이대+그네          NaN          NaN
# 3       1567.0          NaN     조합놀이대+그네          NaN          NaN
# 4       1968.0          NaN          NaN          NaN          NaN
# ...        ...          ...          ...          ...          ...
# 17281   1507.0          NaN      어린이놀이시설          화장실          NaN
# 17282    942.0          NaN      어린이놀이시설          NaN          NaN
# 17283    539.0          NaN      어린이놀이시설          음수대          NaN
# 17284    929.0          NaN      어린이놀이시설          NaN          NaN
# 17285    256.0          NaN      어린이놀이시설          NaN          NaN
#
#       공원보유시설(기타시설)          관리기관명          전화번호
# 0              NaN       경기도 시흥시청  031-310-3869
# 1              NaN  경기도 김포시 공원관리과  031-980-5627
# 2              NaN  경기도 김포시 공원관리과  031-980-5627
# 3              NaN  경기도 김포시 공원관리과  031-980-5627
# 4              NaN  경기도 김포시 공원녹지과  031-980-2344
# ...            ...            ...           ...
# 17281          NaN     서울특별시 강서구청  02-2600-4202
# 17282          NaN     서울특별시 강서구청  02-2600-4202
# 17283          NaN     서울특별시 강서구청  02-2600-4202
# 17284          NaN     서울특별시 강서구청  02-2600-4202
# 17285          NaN     서울특별시 강서구청  02-2600-4202
#
# [17286 rows x 13 columns]
